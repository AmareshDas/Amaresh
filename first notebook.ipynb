# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Amaresh__
#
#  I am a Student

# %% [markdown]
# *I am passionate about pursuing a data science A.I and Machine Learning module,
# Using this we can solve various kind of problem.*

# %% [markdown]
# ### print Helow World Using Print Function ###

# %%
print("Helow World ")
# Out:
# Helow World

# %% [markdown]
# 1. First ordered list item
# 2. Another item
#   * Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
#   1. Ordered sub-list
# 4. And another item.
# * Unordered list can use asterisks
# - Or minuses
# + Or pluses
#
# * [Inline link](https://www.duckduckgo.com)
#
# Colons can be used to align columns.
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned |  1600 |
# | col 2 is      | centered      |    12 |
#
# Strikethrough: ~~double tilde~~
